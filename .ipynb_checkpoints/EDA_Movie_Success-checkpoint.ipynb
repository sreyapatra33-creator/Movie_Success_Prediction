# %% [markdown]
# # EDA (Exploratory Data Analysis)
# - Statistical Analysis
# - Data Visualization

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# Load Clean Data
data = pd.read_csv(r"D:\Capston_Project\cleaned_movie_data.csv")
data.head()
# Out:
#    color      director_name  num_critic_for_reviews  duration  \
# 0  Color      James Cameron                   723.0     178.0
# 1  Color     Gore Verbinski                   302.0     169.0
# 2  Color         Sam Mendes                   602.0     148.0
# 3  Color  Christopher Nolan                   813.0     164.0
# 4  Color        Doug Walker                   110.0     103.0
#
#    director_facebook_likes  actor_3_facebook_likes      actor_2_name  \
# 0                      0.0                   855.0  Joel David Moore
# 1                    563.0                  1000.0     Orlando Bloom
# 2                      0.0                   161.0      Rory Kinnear
# 3                  22000.0                 23000.0    Christian Bale
# 4                    131.0                   369.0        Rob Walker
#
#    actor_1_facebook_likes        gross                           genres  ...  \
# 0                  1000.0  760505847.0  Action|Adventure|Fantasy|Sci-Fi  ...
# ...

# %%
# Copy data
df = data.copy()

# %%
# Check the value of each imdb_binned
imdb_binned = df["imdb_binned"].value_counts()
print(imdb_binned )
# Out:
# imdb_binned
# HIT     3428
# AVG     1524
# FLOP      46
# Name: count, dtype: int64

# %%
# Visualize the distribution
imdb_binned.plot(kind ='bar', color =['green','orange','red'])
plt.title("Movie Success Categories")
plt.xlabel("Category")
plt.ylabel("Number of Movies")
plt.xticks(rotation =0)
plt.show()

# %%
# Split data into Numerical and Categorical Columns
num_columns = df.select_dtypes(include =['number']).columns
print(f"All Numerical Columns Name : ",num_columns)
cat_columns = df.select_dtypes(include =['object']).columns
print(f"All Categorical Columns Name : ",cat_columns)
# Out:
# All Numerical Columns Name :  Index(['num_critic_for_reviews', 'duration', 'director_facebook_likes',
#        'actor_3_facebook_likes', 'actor_1_facebook_likes', 'gross',
#        'num_voted_users', 'cast_total_facebook_likes', 'facenumber_in_poster',
#        'num_user_for_reviews', 'budget', 'title_year',
#        'actor_2_facebook_likes', 'aspect_ratio', 'movie_facebook_likes'],
#       dtype='object')
# All Categorical Columns Name :  Index(['color', 'director_name', 'actor_2_name', 'genres', 'actor_1_name',
#        'actor_3_name', 'plot_keywords', 'language', 'country',
#        'content_rating', 'imdb_binned'],
#       dtype='object')

# %%
#
df_normalized_genres= df.copy()

# %%
# Split Multiple Genres into Individual Genre Records for Analysis
df_normalized_genres["genres_list"] = df_normalized_genres["genres"].str.split("|")
df_exploded = df_normalized_genres.explode("genres_list")
print(df_exploded)
# Out:
#       color     director_name  num_critic_for_reviews  duration  \
# 0     Color     James Cameron                   723.0     178.0
# 0     Color     James Cameron                   723.0     178.0
# 0     Color     James Cameron                   723.0     178.0
# 0     Color     James Cameron                   723.0     178.0
# 1     Color    Gore Verbinski                   302.0     169.0
# ...     ...               ...                     ...       ...
# 4995  Color  Benjamin Roberds                    13.0      76.0
# 4996  Color       Daniel Hsia                    14.0     100.0
# 4996  Color       Daniel Hsia                    14.0     100.0
# 4996  Color       Daniel Hsia                    14.0     100.0
# 4997  Color          Jon Gunn                    43.0      90.0
#
#       director_facebook_likes  actor_3_facebook_likes      actor_2_name  \
# 0                         0.0                   855.0  Joel David Moore
# ...

# %%
# Top 10 genres for hit movie
hit_movies_df = df_exploded[df_exploded["imdb_binned"] == 'HIT']
top10_hit_movies= (hit_movies_df.groupby('genres_list').size().sort_values(ascending = False).head(10))
print(top10_hit_movies)
# Out:
# genres_list
# Drama        2060
# Comedy       1125
# Thriller      903
# Romance       778
# Action        699
# Crime         653
# Adventure     613
# Sci-Fi        376
# Fantasy       375
# Mystery       340
# dtype: int64

# %%
# Top 10 Hit movie Data Visualization

plt.figure(figsize=(12,6))
ax = top10_hit_movies.plot(kind="bar")

for container in ax.containers:
    ax.bar_label(container)

plt.title("Top 10 Genres for HIT Movies")
plt.xlabel("Genres")
plt.ylabel("Number of HIT Movies")
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %%
# Top 10 genres for Flop movie
flop_movies_df = df_exploded[df_exploded["imdb_binned"] == 'FLOP']
top10_flop_movies= (flop_movies_df .groupby('genres_list').size().sort_values(ascending = False).head(10))
print(top10_flop_movies)
# Out:
# genres_list
# Comedy       22
# Action       11
# Adventure    10
# Sci-Fi       10
# Family        8
# Romance       7
# Horror        7
# Fantasy       6
# Drama         6
# Thriller      5
# dtype: int64

# %%
# Top 10 FLOP movie Data Visualization
plt.figure(figsize=(12,6))
ax = top10_flop_movies.plot(kind="bar")

for container in ax.containers:
    ax.bar_label(container)

plt.title("Top 10 Genres for Flop Movies")
plt.xlabel("Genres")
plt.ylabel("Number of Flop Movies")
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %% [markdown]
# # Numerical_columns VS IMDB_BINNED

# %%
# Box plots
for col in num_columns:
    plt.figure(figsize=(10, 5))

    sns.boxplot(
        data=df,
        x='imdb_binned',
        y=col
    )

    plt.title(f"{col} vs IMDb Binned")
    plt.xlabel("IMDb Category")
    plt.ylabel(col)
    plt.show()

# %%
# Scatterplot Visualization
for col in num_columns:
    plt.figure(figsize=(8,5))

    sns.scatterplot(
        data=df,
        x= 'imdb_binned',
        y=col,
    )

    plt.title(f"{col} vs IMDb Binned")
    plt.xlabel("IMDb Category")
    plt.ylabel(col)
    plt.show()

# %% [markdown]
# # Catrgorical_columns VS IMDB_BINNED

# %%
for col in cat_columns:
    if col !='imdb_binned' and col!= 'plot_keywords' and col!='genres':
      top10 = df[col].value_counts().head(10).index
      temp = df[df[col].isin(top10)]
      ct = pd.crosstab(temp[col], temp["imdb_binned"])
      ct.plot(kind = "bar",figsize=(10,5))

    
      plt.title(f"{col} vs IMDb Binned")
      plt.xlabel(col)
      plt.ylabel("Number of Movies")
      plt.xticks(rotation=45)
      plt.legend(title="IMDB_BINNED")
      plt.tight_layout()
      plt.show()
